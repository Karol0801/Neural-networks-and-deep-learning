# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import mkl

mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

# %%
def gaussian(batch, stochastic=False): #tu
    if stochastic: # dodajemy szum z rozkładu normalnego o sredniej 0 i odchyleniu 1.
        return batch + np.random.normal(loc=0.0, scale=1.0, size=batch.shape)
    return batch

def gaussian_derivative(batch):
    return ones(*batch.shape) # gauss to liniowa funkcja aktywacji

# %% [markdown]
# # MNIST dataset

# %%
from mnists import MNIST
mnist = MNIST()
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    if rbm.l2_penalty is not None:
        rbm.M[:-1, :-1] = rbm.M[:-1, :-1] - rbm.learning_rate * rbm.l2_penalty * rbm.W[:-1, :-1]

    rbm.W += rbm.M;
    
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = rbm.hidden_act_func(minibatch @ rbm.W[:, :-1])
    hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size))
    
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(dbn[i].visible_act_func(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(dbn[i].hidden_act_func(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    error = reconstuction_error(dbn[layer_idx], propagated)
    return error

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

def train_dbn(dbn, dataset, monitoring_set, batch_size, epochs_count):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx))
        
        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = 0.9

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # Autoencoder training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %%
def forward_pass(ae, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(ae):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(ae) - 1):
            layer.d_activations = layer.d_activation_fun(z)
            
        visible = layer.activations

    return visible[:, :-1]

def error_backpropagate(ae, batch):
    observations_count = batch.shape[0]

    for layer_idx, layer in reversed(list(enumerate(ae))):
        if layer_idx > 0:
            prev_layer = ae[layer_idx - 1]
            visible = prev_layer.activations
            
            prev_layer.deltas = (layer.deltas @ layer.W[:-1, :].T) * prev_layer.d_activations
        else:
            visible = batch
        
        layer.M *= layer.momentum
        layer.M -= (layer.learning_rate / observations_count) * (visible.T @ layer.deltas)
        
        if layer.l2_penalty > 0:
            layer.M[:-1, :] = layer.M[:-1, :] - layer.learning_rate * layer.l2_penalty * layer.W[:-1, :]
        
        layer.W += layer.M

# %% [markdown]
# ### Cross entropy cost

# %% [markdown]
# Implement cross entropy cost for deep AE. To this end:
# * calculate the cross entropy cost between pixels in the input batch and their reconstructions,
# * sum the cross entropy cost over all pixels and all observations in the minibatch,
# * return average cost per input observation.

# %%
def xentropy(batch, reconstructions): # tu
    observations_count = batch.shape[0]

    # (1-batch).. dla czarnych pikseli (=0)
    cross_entropy = -np.sum(batch * np.log(reconstructions) + (1-batch) * np.log(1-reconstructions))
    return cross_entropy / observations_count

# %% [markdown]
# ### Training procedure

# %%
def train_ae(ae, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    batched_data = chunks(dataset, batch_size)
    
    for batch_idx, batch in enumerate(batched_data):
        reconstructions = forward_pass(ae, batch, True)

        ae[-1].deltas = reconstructions - batch[:, :-1] #tu
        
        error_backpropagate(ae, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_ae_training(ae, train_set, validation_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        start_time = time.time()
        train_ae(ae, train_set, batch_size)
        elapsed = time.time() - start_time

        xe = xentropy(validation_set[:, :-1], forward_pass(ae, validation_set, False))
        print("\telapsed: {0:>2.2f}s, cross-entropy: {1:>2.2f}".format(elapsed, xe))

    print("Training finished!")

# %% [markdown]
# ###  Initializing AE with DBN weights
#
# Implement initialization of AE weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the AE weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_ae(ae, dbn):
    assert(len(ae) == 2*len(dbn))
    idx = 0

    # koder
    for layer_idx in range(len(dbn)):
        ae[idx].W = np.copy(dbn[layer_idx].W[:, :-1])
        idx += 1

    # dekoder - odwracamy kolejność warstw i transponujemy macierze wag
    for layer_idx in range(len(dbn) - 1, -1, -1):
        ae[idx].W = np.copy(dbn[layer_idx].W[:-1, :].T)
        idx += 1

# %% [markdown]
# # Autoencoder for MNIST digits

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_images = np.random.permutation(mnist_train_images)

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE

BATCH_SIZE = 128
EPOCHS_COUNT = 50

RBM_LEARNING_RATE = 0.1
AE_LEARNING_RATE = 0.01
AE_MOMENTUM = 0.9
L2_PENALTY = 0.0002

# %%
from IPython.core.display import HTML

def compare_results(ae, dbn,
                    train_set, validation_set, monitoring_set,
                    batch_size, epochs_count):
    for layer in ae:
        layer.reset()
    
    display(HTML('<h3>Plain AE training</h3>'))
    run_ae_training(ae, train_set, validation_set,
                    batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain AE</h3>'))
    draw_layer_filters(ae[0])
    
    display(HTML('<h3>Input minibatch</h3>'))
    tiles(np.reshape(validation_set[:8*24, :-1],
                     newshape=(8, 24, 28, 28)))
    
    display(HTML('<h3>Plain AE reconstructions</h3>'))
    ae_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24], False),
                                    newshape=(8, 24, 28, 28))
    tiles(ae_reconstructions)
    
    display(HTML('<h3>DBN training</h3>'))
    train_dbn(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in ae:
        layer.reset()
    
    initialize_ae(ae, dbn)
    dbn_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24, :], False),
                                     newshape=(8, 24, 28, 28))
    dbn_rec_cost = xentropy(validation_set[:, :-1],
                            forward_pass(ae, validation_set, False))
    
    display(HTML('<h3>Finetuning pretrained AE</h3>'))
    
    print("Reconstruction cost before finetuning: {0:>2.2f}\n".format(dbn_rec_cost))
    run_ae_training(ae, train_set, validation_set,
                    batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned AE</h3>'))
    draw_layer_filters(ae[0])
    
    display(HTML('<h3>Input minibatch</h3>'))
    tiles(np.reshape(validation_set[:8*24, :-1],
                     newshape=(8, 24, 28, 28)))
    
    display(HTML('<h3>Pretrained AE reconstructions</h3>'))
    tiles(dbn_reconstructions)
    
    display(HTML('<h3>Finetuned AE reconstructions</h3>'))
    ae_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24], False),
                                    newshape=(8, 24, 28, 28))
    tiles(ae_reconstructions)

# %% [markdown]
# ###  Autoencoder network
#
# Define the autoencoder network for MNIST digits. The network structure should be suitable for pretraining with the provided DBN.

# %%
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(256, 128, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(128, 64, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(64, 10, sigmoid, gaussian, RBM_LEARNING_RATE / 10.0, 0.5, L2_PENALTY)
]

ae =  [
    Layer(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(256, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(128, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(64, 10, gaussian, gaussian_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),

    Layer(10, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(64, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(128, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(256, VISIBLE_LAYER_SIZE, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
]

compare_results(ae, dbn,
                mnist_train_images, mnist_test_images,
                monitoring_set,
                BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain AE training</h3>
# Epoch 1:	########################################	elapsed: 10.56s, cross-entropy: 206.27
# Epoch 2:	########################################	elapsed: 10.00s, cross-entropy: 206.18
# Epoch 3:	########################################	elapsed: 8.99s, cross-entropy: 206.16
# Epoch 4:	########################################	elapsed: 8.29s, cross-entropy: 206.15
# Epoch 5:	########################################	elapsed: 9.10s, cross-entropy: 206.14
# Epoch 6:	########################################	elapsed: 8.99s, cross-entropy: 206.13
# Epoch 7:	########################################	elapsed: 11.50s, cross-entropy: 206.13
# Epoch 8:	########################################	elapsed: 9.59s, cross-entropy: 206.12
# Epoch 9:	########################################	elapsed: 9.38s, cross-entropy: 206.12
# Epoch 10:	########################################	elapsed: 9.69s, cross-entropy: 206.11
# Epoch 11:	########################################	elapsed: 10.01s, cross-entropy: 206.11
# Epoch 12:	########################################	elapsed: 9.59s, cross-entropy: 206.10
# Epoch 13:	########################################	elapsed: 9.70s, cross-entropy: 206.10
# Epoch 14:	########################################	elapsed: 10.18s, cross-entropy: 206.09
# Epoch 15:	########################################	elapsed: 9.69s, cross-entropy: 206.09
# Epoch 16:	########################################	elapsed: 8.59s, cross-entropy: 206.09
# Epoch 17:	########################################	elapsed: 9.50s, cross-entropy: 206.08
# Epoch 18:	########################################	elapsed: 9.93s, cross-entropy: 206.08
# Epoch 19:	########################################	elapsed: 9.69s, cross-entropy: 206.08
# Epoch 20:	########################################	elapsed: 9.70s, cross-entropy: 206.07
# Epoch 21:	########################################	elapsed: 9.60s, cross-entropy: 206.07
# Epoch 22:	########################################	elapsed: 9.91s, cross-entropy: 206.07
# Epoch 23:	########################################	elapsed: 9.69s, cross-entropy: 206.06
# Epoch 24:	########################################	elapsed: 10.29s, cross-entropy: 206.06
# Epoch 25:	########################################	elapsed: 10.70s, cross-entropy: 206.06
# Epoch 26:	########################################	elapsed: 9.31s, cross-entropy: 206.06
# Epoch 27:	########################################	elapsed: 10.21s, cross-entropy: 206.05
# Epoch 28:	########################################	elapsed: 10.10s, cross-entropy: 206.05
# Epoch 29:	########################################	elapsed: 10.29s, cross-entropy: 206.05
# Epoch 30:	########################################	elapsed: 9.89s, cross-entropy: 206.05
# Epoch 31:	########################################	elapsed: 9.09s, cross-entropy: 206.05
# Epoch 32:	########################################	elapsed: 9.39s, cross-entropy: 206.04
# Epoch 33:	########################################	elapsed: 10.99s, cross-entropy: 206.04
# Epoch 34:	########################################	elapsed: 9.71s, cross-entropy: 206.04
# Epoch 35:	########################################	elapsed: 9.50s, cross-entropy: 206.04
# Epoch 36:	########################################	elapsed: 9.70s, cross-entropy: 206.04
# Epoch 37:	########################################	elapsed: 9.39s, cross-entropy: 206.03
# Epoch 38:	########################################	elapsed: 9.80s, cross-entropy: 206.03
# Epoch 39:	########################################	elapsed: 11.18s, cross-entropy: 206.03
# Epoch 40:	########################################	elapsed: 9.65s, cross-entropy: 206.03
# Epoch 41:	########################################	elapsed: 9.72s, cross-entropy: 206.03
# Epoch 42:	########################################	elapsed: 9.79s, cross-entropy: 206.02
# Epoch 43:	########################################	elapsed: 9.42s, cross-entropy: 206.02
# Epoch 44:	########################################	elapsed: 10.42s, cross-entropy: 206.02
# Epoch 45:	########################################	elapsed: 9.59s, cross-entropy: 206.02
# Epoch 46:	########################################	elapsed: 9.89s, cross-entropy: 206.02
# Epoch 47:	########################################	elapsed: 9.81s, cross-entropy: 206.02
# Epoch 48:	########################################	elapsed: 9.39s, cross-entropy: 206.02
# Epoch 49:	########################################	elapsed: 8.88s, cross-entropy: 206.01
# Epoch 50:	########################################	elapsed: 11.40s, cross-entropy: 206.01
# Training finished!
# <h3>Input layer filters in the plain AE</h3>
# <h3>Input minibatch</h3>
# <h3>Plain AE reconstructions</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 8.87s, reconstruction error: 31.62
# Epoch 2:	########################################	elapsed: 9.30s, reconstruction error: 24.64
# Epoch 3:	########################################	elapsed: 9.19s, reconstruction error: 21.22
# Epoch 4:	########################################	elapsed: 8.50s, reconstruction error: 19.30
# Epoch 5:	########################################	elapsed: 9.30s, reconstruction error: 17.57
# Epoch 6:	########################################	elapsed: 9.00s, reconstruction error: 15.26
# Epoch 7:	########################################	elapsed: 9.00s, reconstruction error: 13.50
# Epoch 8:	########################################	elapsed: 9.29s, reconstruction error: 12.46
# Epoch 9:	########################################	elapsed: 8.90s, reconstruction error: 11.82
# Epoch 10:	########################################	elapsed: 8.90s, reconstruction error: 11.35
# Epoch 11:	########################################	elapsed: 9.20s, reconstruction error: 11.01
# Epoch 12:	########################################	elapsed: 9.40s, reconstruction error: 10.81
# Epoch 13:	########################################	elapsed: 8.30s, reconstruction error: 10.66
# Epoch 14:	########################################	elapsed: 9.40s, reconstruction error: 10.46
# Epoch 15:	########################################	elapsed: 9.11s, reconstruction error: 10.18
# Epoch 16:	########################################	elapsed: 8.60s, reconstruction error: 10.08
# Epoch 17:	########################################	elapsed: 8.90s, reconstruction error: 9.99
# Epoch 18:	########################################	elapsed: 10.50s, reconstruction error: 10.06
# Epoch 19:	########################################	elapsed: 10.20s, reconstruction error: 9.92
# Epoch 20:	########################################	elapsed: 10.39s, reconstruction error: 9.78
# Epoch 21:	########################################	elapsed: 8.79s, reconstruction error: 9.81
# Epoch 22:	########################################	elapsed: 9.20s, reconstruction error: 9.65
# Epoch 23:	########################################	elapsed: 9.00s, reconstruction error: 9.55
# Epoch 24:	########################################	elapsed: 9.80s, reconstruction error: 9.60
# Epoch 25:	########################################	elapsed: 9.90s, reconstruction error: 9.51
# Epoch 26:	########################################	elapsed: 8.10s, reconstruction error: 9.46
# Epoch 27:	########################################	elapsed: 9.20s, reconstruction error: 9.38
# Epoch 28:	########################################	elapsed: 9.80s, reconstruction error: 9.29
# Epoch 29:	########################################	elapsed: 9.20s, reconstruction error: 9.16
# Epoch 30:	########################################	elapsed: 8.90s, reconstruction error: 9.16
# Epoch 31:	########################################	elapsed: 9.40s, reconstruction error: 9.23
# Epoch 32:	########################################	elapsed: 9.59s, reconstruction error: 9.22
# Epoch 33:	########################################	elapsed: 9.60s, reconstruction error: 9.05
# Epoch 34:	########################################	elapsed: 9.00s, reconstruction error: 9.15
# Epoch 35:	########################################	elapsed: 9.20s, reconstruction error: 9.17
# Epoch 36:	########################################	elapsed: 9.10s, reconstruction error: 9.12
# Epoch 37:	########################################	elapsed: 9.90s, reconstruction error: 9.19
# Epoch 38:	########################################	elapsed: 8.39s, reconstruction error: 8.84
# Epoch 39:	########################################	elapsed: 9.90s, reconstruction error: 8.91
# Epoch 40:	########################################	elapsed: 9.70s, reconstruction error: 8.93
# Epoch 41:	########################################	elapsed: 9.00s, reconstruction error: 8.87
# Epoch 42:	########################################	elapsed: 8.40s, reconstruction error: 8.88
# Epoch 43:	########################################	elapsed: 9.30s, reconstruction error: 8.90
# Epoch 44:	########################################	elapsed: 8.69s, reconstruction error: 8.84
# Epoch 45:	########################################	elapsed: 9.40s, reconstruction error: 8.86
# Epoch 46:	########################################	elapsed: 9.90s, reconstruction error: 8.78
# Epoch 47:	########################################	elapsed: 9.40s, reconstruction error: 8.90
# Epoch 48:	########################################	elapsed: 8.90s, reconstruction error: 8.76
# Epoch 49:	########################################	elapsed: 8.81s, reconstruction error: 8.80
# Epoch 50:	########################################	elapsed: 9.20s, reconstruction error: 8.71
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 3.40s, reconstruction error: 20.39
# Epoch 2:	########################################	elapsed: 3.70s, reconstruction error: 15.80
# Epoch 3:	########################################	elapsed: 4.10s, reconstruction error: 13.68
# Epoch 4:	########################################	elapsed: 3.80s, reconstruction error: 12.17
# Epoch 5:	########################################	elapsed: 4.19s, reconstruction error: 11.17
# Epoch 6:	########################################	elapsed: 3.50s, reconstruction error: 9.14
# Epoch 7:	########################################	elapsed: 3.70s, reconstruction error: 8.14
# Epoch 8:	########################################	elapsed: 3.70s, reconstruction error: 7.42
# Epoch 9:	########################################	elapsed: 3.90s, reconstruction error: 7.00
# Epoch 10:	########################################	elapsed: 3.70s, reconstruction error: 6.69
# Epoch 11:	########################################	elapsed: 3.60s, reconstruction error: 6.46
# Epoch 12:	########################################	elapsed: 3.89s, reconstruction error: 6.30
# Epoch 13:	########################################	elapsed: 3.71s, reconstruction error: 6.25
# Epoch 14:	########################################	elapsed: 3.40s, reconstruction error: 6.07
# Epoch 15:	########################################	elapsed: 3.90s, reconstruction error: 6.00
# Epoch 16:	########################################	elapsed: 3.30s, reconstruction error: 5.81
# Epoch 17:	########################################	elapsed: 3.61s, reconstruction error: 5.73
# Epoch 18:	########################################	elapsed: 3.71s, reconstruction error: 5.69
# Epoch 19:	########################################	elapsed: 3.70s, reconstruction error: 5.60
# Epoch 20:	########################################	elapsed: 3.50s, reconstruction error: 5.61
# Epoch 21:	########################################	elapsed: 4.20s, reconstruction error: 5.59
# Epoch 22:	########################################	elapsed: 3.80s, reconstruction error: 5.58
# Epoch 23:	########################################	elapsed: 3.80s, reconstruction error: 5.50
# Epoch 24:	########################################	elapsed: 3.79s, reconstruction error: 5.48
# Epoch 25:	########################################	elapsed: 3.80s, reconstruction error: 5.45
# Epoch 26:	########################################	elapsed: 3.70s, reconstruction error: 5.42
# Epoch 27:	########################################	elapsed: 3.41s, reconstruction error: 5.30
# Epoch 28:	########################################	elapsed: 3.40s, reconstruction error: 5.33
# Epoch 29:	########################################	elapsed: 3.90s, reconstruction error: 5.20
# Epoch 30:	########################################	elapsed: 3.50s, reconstruction error: 5.29
# Epoch 31:	########################################	elapsed: 3.49s, reconstruction error: 5.18
# Epoch 32:	########################################	elapsed: 3.80s, reconstruction error: 5.33
# Epoch 33:	########################################	elapsed: 3.40s, reconstruction error: 5.19
# Epoch 34:	########################################	elapsed: 3.69s, reconstruction error: 5.19
# Epoch 35:	########################################	elapsed: 3.90s, reconstruction error: 5.14
# Epoch 36:	########################################	elapsed: 3.90s, reconstruction error: 5.19
# Epoch 37:	########################################	elapsed: 3.40s, reconstruction error: 5.13
# Epoch 38:	########################################	elapsed: 3.60s, reconstruction error: 5.06
# Epoch 39:	########################################	elapsed: 3.90s, reconstruction error: 5.10
# Epoch 40:	########################################	elapsed: 3.40s, reconstruction error: 5.06
# Epoch 41:	########################################	elapsed: 3.50s, reconstruction error: 5.10
# Epoch 42:	########################################	elapsed: 3.30s, reconstruction error: 5.18
# Epoch 43:	########################################	elapsed: 3.51s, reconstruction error: 5.03
# Epoch 44:	########################################	elapsed: 3.40s, reconstruction error: 5.07
# Epoch 45:	########################################	elapsed: 4.01s, reconstruction error: 5.06
# Epoch 46:	########################################	elapsed: 3.70s, reconstruction error: 5.04
# Epoch 47:	########################################	elapsed: 3.40s, reconstruction error: 5.01
# Epoch 48:	########################################	elapsed: 4.40s, reconstruction error: 5.02
# Epoch 49:	########################################	elapsed: 3.70s, reconstruction error: 5.10
# Epoch 50:	########################################	elapsed: 4.09s, reconstruction error: 5.10
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 1.20s, reconstruction error: 14.39
# Epoch 2:	########################################	elapsed: 0.91s, reconstruction error: 10.71
# Epoch 3:	########################################	elapsed: 1.00s, reconstruction error: 9.24
# Epoch 4:	########################################	elapsed: 1.00s, reconstruction error: 8.31
# Epoch 5:	########################################	elapsed: 1.11s, reconstruction error: 7.52
# Epoch 6:	########################################	elapsed: 1.01s, reconstruction error: 6.32
# Epoch 7:	########################################	elapsed: 1.02s, reconstruction error: 5.58
# Epoch 8:	########################################	elapsed: 1.01s, reconstruction error: 5.16
# Epoch 9:	########################################	elapsed: 1.01s, reconstruction error: 4.90
# Epoch 10:	########################################	elapsed: 1.10s, reconstruction error: 4.79
# Epoch 11:	########################################	elapsed: 0.99s, reconstruction error: 4.68
# Epoch 12:	########################################	elapsed: 0.90s, reconstruction error: 4.59
# Epoch 13:	########################################	elapsed: 1.19s, reconstruction error: 4.50
# Epoch 14:	########################################	elapsed: 1.01s, reconstruction error: 4.46
# Epoch 15:	########################################	elapsed: 1.01s, reconstruction error: 4.39
# Epoch 16:	########################################	elapsed: 1.01s, reconstruction error: 4.36
# Epoch 17:	########################################	elapsed: 1.10s, reconstruction error: 4.36
# Epoch 18:	########################################	elapsed: 1.10s, reconstruction error: 4.28
# Epoch 19:	########################################	elapsed: 1.11s, reconstruction error: 4.27
# Epoch 20:	########################################	elapsed: 1.10s, reconstruction error: 4.25
# Epoch 21:	########################################	elapsed: 1.01s, reconstruction error: 4.21
# Epoch 22:	########################################	elapsed: 1.10s, reconstruction error: 4.15
# Epoch 23:	########################################	elapsed: 1.01s, reconstruction error: 4.18
# Epoch 24:	########################################	elapsed: 1.10s, reconstruction error: 4.14
# Epoch 25:	########################################	elapsed: 1.10s, reconstruction error: 4.14
# Epoch 26:	########################################	elapsed: 1.09s, reconstruction error: 4.15
# Epoch 27:	########################################	elapsed: 1.01s, reconstruction error: 4.04
# Epoch 28:	########################################	elapsed: 0.91s, reconstruction error: 4.10
# Epoch 29:	########################################	elapsed: 0.81s, reconstruction error: 4.07
# Epoch 30:	########################################	elapsed: 1.00s, reconstruction error: 4.11
# Epoch 31:	########################################	elapsed: 0.99s, reconstruction error: 3.99
# Epoch 32:	########################################	elapsed: 1.00s, reconstruction error: 4.02
# Epoch 33:	########################################	elapsed: 1.01s, reconstruction error: 4.07
# Epoch 34:	########################################	elapsed: 1.00s, reconstruction error: 4.03
# Epoch 35:	########################################	elapsed: 1.01s, reconstruction error: 4.02
# Epoch 36:	########################################	elapsed: 1.01s, reconstruction error: 4.00
# Epoch 37:	########################################	elapsed: 0.81s, reconstruction error: 3.94
# Epoch 38:	########################################	elapsed: 1.01s, reconstruction error: 4.05
# Epoch 39:	########################################	elapsed: 0.91s, reconstruction error: 3.98
# Epoch 40:	########################################	elapsed: 0.91s, reconstruction error: 3.93
# Epoch 41:	########################################	elapsed: 0.91s, reconstruction error: 4.04
# Epoch 42:	########################################	elapsed: 1.00s, reconstruction error: 4.00
# Epoch 43:	########################################	elapsed: 0.91s, reconstruction error: 3.95
# Epoch 44:	########################################	elapsed: 1.01s, reconstruction error: 3.97
# Epoch 45:	########################################	elapsed: 1.00s, reconstruction error: 3.92
# Epoch 46:	########################################	elapsed: 1.10s, reconstruction error: 3.90
# Epoch 47:	########################################	elapsed: 0.91s, reconstruction error: 3.99
# Epoch 48:	########################################	elapsed: 1.11s, reconstruction error: 3.98
# Epoch 49:	########################################	elapsed: 1.01s, reconstruction error: 3.95
# Epoch 50:	########################################	elapsed: 1.10s, reconstruction error: 3.91
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 0.62s, reconstruction error: 11.57
# Epoch 2:	########################################	elapsed: 0.60s, reconstruction error: 10.12
# Epoch 3:	########################################	elapsed: 0.59s, reconstruction error: 9.21
# Epoch 4:	########################################	elapsed: 0.60s, reconstruction error: 8.79
# Epoch 5:	########################################	elapsed: 0.60s, reconstruction error: 8.55
# Epoch 6:	########################################	elapsed: 0.60s, reconstruction error: 8.34
# Epoch 7:	########################################	elapsed: 0.59s, reconstruction error: 8.44
# Epoch 8:	########################################	elapsed: 0.60s, reconstruction error: 8.41
# Epoch 9:	########################################	elapsed: 0.60s, reconstruction error: 8.46
# Epoch 10:	########################################	elapsed: 0.60s, reconstruction error: 8.51
# Epoch 11:	########################################	elapsed: 0.59s, reconstruction error: 8.54
# Epoch 12:	########################################	elapsed: 0.60s, reconstruction error: 8.59
# Epoch 13:	########################################	elapsed: 0.70s, reconstruction error: 8.63
# Epoch 14:	########################################	elapsed: 0.50s, reconstruction error: 8.66
# Epoch 15:	########################################	elapsed: 0.59s, reconstruction error: 8.70
# Epoch 16:	########################################	elapsed: 0.60s, reconstruction error: 8.74
# Epoch 17:	########################################	elapsed: 0.60s, reconstruction error: 8.77
# Epoch 18:	########################################	elapsed: 0.59s, reconstruction error: 8.82
# Epoch 19:	########################################	elapsed: 0.60s, reconstruction error: 8.82
# Epoch 20:	########################################	elapsed: 0.60s, reconstruction error: 8.85
# Epoch 21:	########################################	elapsed: 0.60s, reconstruction error: 8.89
# Epoch 22:	########################################	elapsed: 0.60s, reconstruction error: 8.89
# Epoch 23:	########################################	elapsed: 0.63s, reconstruction error: 8.94
# Epoch 24:	########################################	elapsed: 0.60s, reconstruction error: 8.98
# Epoch 25:	########################################	elapsed: 0.59s, reconstruction error: 9.00
# Epoch 26:	########################################	elapsed: 0.60s, reconstruction error: 9.02
# Epoch 27:	########################################	elapsed: 0.50s, reconstruction error: 9.03
# Epoch 28:	########################################	elapsed: 0.62s, reconstruction error: 9.09
# Epoch 29:	########################################	elapsed: 0.59s, reconstruction error: 9.13
# Epoch 30:	########################################	elapsed: 0.70s, reconstruction error: 9.15
# Epoch 31:	########################################	elapsed: 0.60s, reconstruction error: 9.19
# Epoch 32:	########################################	elapsed: 0.59s, reconstruction error: 9.18
# Epoch 33:	########################################	elapsed: 0.60s, reconstruction error: 9.22
# Epoch 34:	########################################	elapsed: 0.60s, reconstruction error: 9.22
# Epoch 35:	########################################	elapsed: 0.60s, reconstruction error: 9.25
# Epoch 36:	########################################	elapsed: 0.61s, reconstruction error: 9.27
# Epoch 37:	########################################	elapsed: 0.62s, reconstruction error: 9.28
# Epoch 38:	########################################	elapsed: 0.59s, reconstruction error: 9.30
# Epoch 39:	########################################	elapsed: 0.60s, reconstruction error: 9.29
# Epoch 40:	########################################	elapsed: 0.60s, reconstruction error: 9.33
# Epoch 41:	########################################	elapsed: 0.48s, reconstruction error: 9.34
# Epoch 42:	########################################	elapsed: 0.51s, reconstruction error: 9.39
# Epoch 43:	########################################	elapsed: 0.62s, reconstruction error: 9.40
# Epoch 44:	########################################	elapsed: 0.50s, reconstruction error: 9.40
# Epoch 45:	########################################	elapsed: 0.59s, reconstruction error: 9.39
# Epoch 46:	########################################	elapsed: 0.60s, reconstruction error: 9.44
# Epoch 47:	########################################	elapsed: 0.70s, reconstruction error: 9.45
# Epoch 48:	########################################	elapsed: 0.60s, reconstruction error: 9.42
# Epoch 49:	########################################	elapsed: 0.60s, reconstruction error: 9.46
# Epoch 50:	########################################	elapsed: 0.60s, reconstruction error: 9.41
# <h3>Finetuning pretrained AE</h3>
# Reconstruction cost before finetuning: 136.05
#
# Epoch 1:	########################################	elapsed: 10.69s, cross-entropy: 106.77
# Epoch 2:	########################################	elapsed: 12.83s, cross-entropy: 103.85
# Epoch 3:	########################################	elapsed: 13.30s, cross-entropy: 102.15
# Epoch 4:	########################################	elapsed: 13.60s, cross-entropy: 100.89
# Epoch 5:	########################################	elapsed: 12.39s, cross-entropy: 99.81
# Epoch 6:	########################################	elapsed: 12.81s, cross-entropy: 98.90
# Epoch 7:	########################################	elapsed: 13.71s, cross-entropy: 98.12
# Epoch 8:	########################################	elapsed: 12.89s, cross-entropy: 97.42
# Epoch 9:	########################################	elapsed: 12.40s, cross-entropy: 96.78
# Epoch 10:	########################################	elapsed: 11.52s, cross-entropy: 96.23
# Epoch 11:	########################################	elapsed: 11.99s, cross-entropy: 96.01
# Epoch 12:	########################################	elapsed: 12.98s, cross-entropy: 95.72
# Epoch 13:	########################################	elapsed: 12.69s, cross-entropy: 94.84
# Epoch 14:	########################################	elapsed: 13.00s, cross-entropy: 94.71
# Epoch 15:	########################################	elapsed: 12.99s, cross-entropy: 94.80
# Epoch 16:	########################################	elapsed: 13.18s, cross-entropy: 94.65
# Epoch 17:	########################################	elapsed: 12.99s, cross-entropy: 94.81
# Epoch 18:	########################################	elapsed: 12.40s, cross-entropy: 95.21
# Epoch 19:	########################################	elapsed: 13.39s, cross-entropy: 95.41
# Epoch 20:	########################################	elapsed: 12.67s, cross-entropy: 94.27
# Epoch 21:	########################################	elapsed: 13.49s, cross-entropy: 93.85
# Epoch 22:	########################################	elapsed: 12.70s, cross-entropy: 93.62
# Epoch 23:	########################################	elapsed: 13.09s, cross-entropy: 93.15
# Epoch 24:	########################################	elapsed: 12.90s, cross-entropy: 92.70
# Epoch 25:	########################################	elapsed: 12.80s, cross-entropy: 92.39
# Epoch 26:	########################################	elapsed: 12.98s, cross-entropy: 92.21
# Epoch 27:	########################################	elapsed: 13.60s, cross-entropy: 92.00
# Epoch 28:	########################################	elapsed: 14.40s, cross-entropy: 91.90
# Epoch 29:	########################################	elapsed: 13.19s, cross-entropy: 91.84
# Epoch 30:	########################################	elapsed: 13.29s, cross-entropy: 91.57
# Epoch 31:	########################################	elapsed: 12.82s, cross-entropy: 91.43
# Epoch 32:	########################################	elapsed: 13.49s, cross-entropy: 91.92
# Epoch 33:	########################################	elapsed: 13.49s, cross-entropy: 93.35
# Epoch 34:	########################################	elapsed: 12.89s, cross-entropy: 93.89
# Epoch 35:	########################################	elapsed: 13.99s, cross-entropy: 93.09
# Epoch 36:	########################################	elapsed: 13.19s, cross-entropy: 92.40
# Epoch 37:	########################################	elapsed: 13.98s, cross-entropy: 92.24
# Epoch 38:	########################################	elapsed: 13.88s, cross-entropy: 93.55
# Epoch 39:	########################################	elapsed: 11.69s, cross-entropy: 94.05
# Epoch 40:	########################################	elapsed: 13.49s, cross-entropy: 93.67
# Epoch 41:	########################################	elapsed: 12.89s, cross-entropy: 94.36
# Epoch 42:	########################################	elapsed: 13.29s, cross-entropy: 93.75
# Epoch 43:	########################################	elapsed: 12.89s, cross-entropy: 92.04
# Epoch 44:	########################################	elapsed: 13.28s, cross-entropy: 91.38
# Epoch 45:	########################################	elapsed: 13.00s, cross-entropy: 91.12
# Epoch 46:	########################################	elapsed: 13.39s, cross-entropy: 90.87
# Epoch 47:	########################################	elapsed: 12.79s, cross-entropy: 90.62
# Epoch 48:	########################################	elapsed: 13.01s, cross-entropy: 90.70
# Epoch 49:	########################################	elapsed: 12.91s, cross-entropy: 91.36
# Epoch 50:	########################################	elapsed: 13.48s, cross-entropy: 91.33
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned AE</h3>
# <h3>Input minibatch</h3>
# <h3>Pretrained AE reconstructions</h3>
# <h3>Finetuned AE reconstructions</h3>
